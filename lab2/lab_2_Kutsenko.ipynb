# %%
from IPython.display import display, Markdown

text = """
# Лабораторна робота №2
**Тема:** Налагоджування та робота в середовищі Anaconda+Quarto
**Виконав:** студент Куценко Данило

### Відповіді на контрольні запитання:

**1. Що таке pip і conda та чим вони відрізняються між собою?**
`pip` — це менеджер пакетів для Python. Натомість `conda` — це програма вищого рівня, яка поєднує функції менеджера пакетів та системи керування віртуальними середовищами.

**2. Як виглядатиме виконання пунктів 1-3 індивідуального завдання за допомогою Virtualenv?**
Створення середовища: `python -m venv Kutsenko_OpenCV`
Активація (для Windows): `Kutsenko_OpenCV\\Scripts\\activate`
Встановлення пакетів: `pip install opencv-python numpy matplotlib`

**5. Як виконати компіляцію вхідного документа Jupyter Notebook з його середовища?**
У меню File -> Download as -> HTML (.html).

**6. Як виконати компіляцію вхідного документа у Quarto?**
Команда: `quarto preview lab_2_Kutsenko.ipynb`
"""
# Выводим красивый текст
display(Markdown(text))

# Выполняем код для сортировки (Задание 4)
def usual_sort(nums):
    nums.sort()
    return nums

random_list = [10, -5, 42, 18, 0, 7]
print("\n--- Завдання 4: Сортування масиву ---")
print("Відсортований масив:", usual_sort(random_list))
# Out:
# # Лабораторна робота №2
# **Тема:** Налагоджування та робота в середовищі Anaconda+Quarto
# **Виконав:** студент Куценко Данило
#
# ### Відповіді на контрольні запитання:
#
# **1. Що таке pip і conda та чим вони відрізняються між собою?**
# `pip` — це менеджер пакетів для Python. Натомість `conda` — це програма вищого рівня, яка поєднує функції менеджера пакетів та системи керування віртуальними середовищами.
#
# **2. Як виглядатиме виконання пунктів 1-3 індивідуального завдання за допомогою Virtualenv?**
# Створення середовища: `python -m venv Kutsenko_OpenCV`
# Активація (для Windows): `Kutsenko_OpenCV\Scripts\activate`
# Встановлення пакетів: `pip install opencv-python numpy matplotlib`
#
# **5. Як виконати компіляцію вхідного документа Jupyter Notebook з його середовища?**
# У меню File -> Download as -> HTML (.html).
#
# **6. Як виконати компіляцію вхідного документа у Quarto?**
# Команда: `quarto preview lab_2_Kutsenko.ipynb`
# --- Завдання 4: Сортування масиву ---
# ...
